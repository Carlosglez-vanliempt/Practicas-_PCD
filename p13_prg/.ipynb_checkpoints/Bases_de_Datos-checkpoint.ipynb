# %% [markdown]
# # Base de Datos

# %% [markdown]
# ###### Carlos Gonzalez van Liempt

# %%
import pyrebase as py

# %%
firebaseConfig = {
  "apiKey": "AIzaSyAfMJEIxKfVX_eKTrIoVdXg09QY9USMlzc",
  "authDomain": "functions-real-case-pbi.firebaseapp.com",
  "databaseURL": "https://functions-real-case-pbi-default-rtdb.firebaseio.com",
  "projectId": "functions-real-case-pbi",
  "storageBucket": "functions-real-case-pbi.appspot.com",
  "messagingSenderId": "212033978800",
  "appId": "1:212033978800:web:e1d63004db5d6c6fe89675",
  "measurementId": "G-N23MB60FQV"
}; ##Json sacado de la configuracion del servidor de pyrebase

# %% [markdown]
# ### Iniciar la app

# %%
fire = py.initialize_app(firebaseConfig)

# %%
auth=fire.auth()

# %%
ddbb=fire.database()

# %%
user = auth.create_user_with_email_and_password('22067726a@g.es','6516981981998')

# %%
user = auth.sign_in_with_email_and_password('22067726a@g.es','6516981981998')

# %%
user
# Out:
# {'kind': 'identitytoolkit#VerifyPasswordResponse',
#  'localId': 'ISHjUodJpuPmltd6kICqsgKpqbp2',
#  'email': '22067726a@g.es',
#  'displayName': '',
#  'idToken': 'eyJhbGciOiJSUzI1NiIsImtpZCI6IjQ3OTg5ZTU4ZWU1ODM4OTgzZDhhNDQwNWRlOTVkYTllZTZmNWVlYjgiLCJ0eXAiOiJKV1QifQ.....Tcr98VDGhg7AZc1r76FREV5PC6igjS4mq4A1fK-7zqxPGbE4WqFWsu8cDYUTBjELdROBYtbL26vHWYETdZ9xc42E14uLZNv_pvUnKDszTrwfSeZXBjAY-DljGtuZqOrXw_TiV2X6NNI3ivj2yl3uaH6zibQZq00CZGKxNI_lsxx5tzjlIOxfth5MVb5BhxMh-MDjMq6anW1g-X5CES23EHNfQXkgHXg6qObu9ido1KwPIcCkhDL5ZlBodWD6qz_23SQhHVhtbWnH9UvbTqwVTVSx-ng6DC7L6o_K0bOTGQvk6lm5yQrHVfgKYPHiP_VyiQRe30EglHBCjmJSIJC3ZQ',
#  'registered': True,
#  'refreshToken': 'AFxQ4_puhMIpFPG3tg2tfX2mcM4PnuN0PdpQyB-HvZpc7s93oo1wgUpLhY-n_SK8ip53XPxvnuZ_wLatHsobaXMecshwGZCfpgtvgC22JQSrQti56Kp0ucrDgS-jAekbcPtdCqO-UYXk-PRiP_o1hC2vvYJ0tNCiCdmX4y7xOnc9Z6ctwmQfxcbqYyN-HLesre0oi8fzAhHpMzVQh31CP5Zqioc80EC44lNa6RYaIebc7ikQu4YjN_8',
#  'expiresIn': '3600'}

# %% [markdown]
# ### Grab, Alvaro's node

# %%
user = auth.refresh(user['refreshToken'])

# %%
user['idToken']
# Out:
# 'eyJhbGciOiJSUzI1NiIsImtpZCI6IjQ3OTg5ZTU4ZWU1ODM4OTgzZDhhNDQwNWRlOTVkYTllZTZmNWVlYjgiLCJ0eXAiOiJKV1QifQ.....TkZIuAJ9IepQBG7owP1i6KkBWRZxM4gzYV896PE9uHmOiByQ_No4hiyRVaM8IvO7sTwezqG8HteefOlvliy_aXpcJCaci1D3Ty16GF8GAmEdDjT6XxVepI62dRfuzUQ4oe2xgkwbXPYAt_sqTaQVhy00JamKTxTCiDuEiUfMkV0IlDnNo6d2ivhkRQiuTHWGjPYupsj2AemY_QUaICEweOumJC0o1C_OyvylhaYKiCAbJlNXJ6gwr6QXSqBtX_QDOvhLTO_AWU8ETC39GcGBEySDBWmYmcpoSY5iJeQSitNqzRxcQOuJL9EM6NPRe06C6TB30dAbdSnMxrboPXsUmw'

# %%
data=ddbb.child('22067726').get()

# %% [markdown]
# ### val(), returns al query data (k,v)

# %%
data.val()
# Out:
# OrderedDict([('QR',
#               'HC1:NCFOXN%TSMAHN-HFSC41O/XMD/20MSM52$IT1WGTJPBBJRH5$JUQC0.HLE%9 W2:ZH6I1$4JN:IN1MPK9V L9L69UEG%6ZZ1 /E+T62VEV EII6$DM7Y6E%61H67%EVHA0T932QZJDKK9+OC+G9QJPNF67J6QW6D9RRZM6PPM4MP6FP8QD/9:G9%PPLTA8C9B212+P:S9HR9EB6C2$J+PEYMS:CSPZI$%P$K3$OHBW24FAL86H0VOCIL8-TIKR3T3+7A.N88J4R$FBMA2 U6QS25P0QIRR97I2HOAXL92L0. KOKGTM8$M8SNCT64RR7+V4YC5/HQR%RHCR Q2:PI/E2$4JY/KQT2D4HP4HREFMSV78W37JKN$E7WGV /KXU2$OFMDFU5HNK78B5ZMV PN.TV/Y06ALG%IDC5 EGL+92+0AVO6ZR- A7KB*KYQTKWT4S83U5J752MDEKUGR2::4R8I5XSZ/CHIVZLAQYOFWM%U23I4GHDZX73$JI3NSBWQ$EY:RYX7M19N8KOEJFSSSGL4WU57EO.V/3FBZQEML840$SHA4'),
#              ('cliente1',
#               {'-Mpvmzx0EUOmmvSh84Tf': 'Desde el cliente1',
#                '-Mpvmzz2NR6KD_IrRoSF': 'Mi nombre es Carlos Gonzalez van Liempt, expediente 22067726',
#                '-Mpvn-05kcc8d_N1sLav': 'Mi ip es 192.168.1.1',
#                '-Mpvn-2CMCYunbAK1n_0': 'El puerto que uso es: 35467',
#                'user': {'email': '22067720@g.es',
# ...

# %% [markdown]
# ### key(),returns only keys from object

# %%
data.key()
# Out:
# '22067726'

# %% [markdown]
# ### each(), retuns a list of objects, you can call val() and key()

# %%
all_exp = db.get()

# %%
for exp in all_exp.each():
    print(f'\nEstudiante : {exp.key()}\n')
    print(exp.val())
# Out:
# Estudiante : 21535220
#
# {'server': {'0': 'Darwin', '1': 'Christians-MacBook-Pro15.local', '2': '21.1.0', '3': 'Darwin Kernel Version 21.1.0: Wed Oct 13 17:33:23 PDT 2021; root:xnu-8019.41.5~1/RELEASE_X86_64', '4': 'x86_64', '5': 'i386', '21535220': {'token': {'apiKey': 'AIzaSyAfMJEIxKfVX_eKTrIoVdXg09QY9USMlzc', 'appId': '1:212033978800:web:e1d63004db5d6c6fe89675', 'authDomain': 'functions-real-case-pbi.firebaseapp.com', 'databaseURL': 'https://functions-real-case-pbi-default-rtdb.firebaseio.com', 'measurementId': 'G-N23MB60FQV', 'messagingSenderId': '212033978800', 'projectId': 'functions-real-case-pbi', 'storageBucket': 'functions-real-case-pbi.appspot.com'}}, 'A_c': 100, 'A_f': 40, 'B_c': 34, 'B_f': 200, 'cores': 8, 'tiempo_par': 0.34, 'tiempo_sec': 20.34, 'veces_mas_r': '20,45'}}
#
# Estudiante : 21844997
#
# ...

# %% [markdown]
# ### shallow(), returns just keys at path

# %%
somebody=db.child('22067726').shallow().get()

# %%
somebody

# %% [markdown]
# ### update() updaete data in specific path, Subir Codigo QR CLASS PARTICIPATION

# %%
crhistianQRcodificated = 'HC1:NCFOXN%TSMAHN-HFSC41O/XMD/20MSM52$IT1WGTJPBBJRH5$JUQC0.HLE%9 W2:ZH6I1$4JN:IN1MPK9V L9L69UEG%6ZZ1 /E+T62VEV EII6$DM7Y6E%61H67%EVHA0T932QZJDKK9+OC+G9QJPNF67J6QW6D9RRZM6PPM4MP6FP8QD/9:G9%PPLTA8C9B212+P:S9HR9EB6C2$J+PEYMS:CSPZI$%P$K3$OHBW24FAL86H0VOCIL8-TIKR3T3+7A.N88J4R$FBMA2 U6QS25P0QIRR97I2HOAXL92L0. KOKGTM8$M8SNCT64RR7+V4YC5/HQR%RHCR Q2:PI/E2$4JY/KQT2D4HP4HREFMSV78W37JKN$E7WGV /KXU2$OFMDFU5HNK78B5ZMV PN.TV/Y06ALG%IDC5 EGL+92+0AVO6ZR- A7KB*KYQTKWT4S83U5J752MDEKUGR2::4R8I5XSZ/CHIVZLAQYOFWM%U23I4GHDZX73$JI3NSBWQ$EY:RYX7M19N8KOEJFSSSGL4WU57EO.V/3FBZQEML840$SHA4'

# %%
db.child('22067726').update({'QR' :crhistianQRcodificated})
# Out:
# {'QR': 'HC1:NCFOXN%TSMAHN-HFSC41O/XMD/20MSM52$IT1WGTJPBBJRH5$JUQC0.HLE%9 W2:ZH6I1$4JN:IN1MPK9V L9L69UEG%6ZZ1 /E+T62VEV EII6$DM7Y6E%61H67%EVHA0T932QZJDKK9+OC+G9QJPNF67J6QW6D9RRZM6PPM4MP6FP8QD/9:G9%PPLTA8C9B212+P:S9HR9EB6C2$J+PEYMS:CSPZI$%P$K3$OHBW24FAL86H0VOCIL8-TIKR3T3+7A.N88J4R$FBMA2 U6QS25P0QIRR97I2HOAXL92L0. KOKGTM8$M8SNCT64RR7+V4YC5/HQR%RHCR Q2:PI/E2$4JY/KQT2D4HP4HREFMSV78W37JKN$E7WGV /KXU2$OFMDFU5HNK78B5ZMV PN.TV/Y06ALG%IDC5 EGL+92+0AVO6ZR- A7KB*KYQTKWT4S83U5J752MDEKUGR2::4R8I5XSZ/CHIVZLAQYOFWM%U23I4GHDZX73$JI3NSBWQ$EY:RYX7M19N8KOEJFSSSGL4WU57EO.V/3FBZQEML840$SHA4'}
